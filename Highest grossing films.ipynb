# %%
from bs4 import BeautifulSoup
import requests

# %%
url= 'https://en.wikipedia.org/wiki/List_of_highest-grossing_films'
agent = {"User-Agent":'Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/59.0.3071.115 Safari/537.36'}
html= requests.get(url, headers= agent)
print(html)
# Out:
# <Response [200]>

# %%
html_page= BeautifulSoup(html.text, 'html')

# %%
tables= html_page.findAll('table')

# %%
table= tables[0]

# %%
table
# Out:
# <table class="wikitable sortable plainrowheaders sticky-header col4right col5center col6center" style="margin:auto; margin:auto;">
# <caption>Highest-grossing films<sup class="reference" id="cite_ref-12"><a href="#cite_note-12">[12]</a></sup>
# </caption>
# <tbody><tr>
# <th>Rank
# </th>
# <th>Peak
# </th>
# <th>Title
# </th>
# <th>Worldwide gross
# </th>
# <th>Year
# </th>
# <th class="unsortable"><abbr title="References">Ref</abbr>
# </th></tr>
# <tr>
# <td>1
# </td>
# <td>1
# </td>
# <th scope="row"><i><a href="/wiki/Avatar_(2009_film)" title="Avatar (2009 film)">Avatar</a></i>
# </th>
# <td>$2,923,706,026
# </td>
# <td>2009
# </td>
# <td><sup class="reference" id="cite_ref-avatar_13-0"><a href="#cite_note-avatar-13">[# 1]</a></sup><sup class="reference" id="cite_ref-avatar_peak_14-0"><a href="#cite_note-avatar_peak-14">[# 2]</a></sup>
# </td></tr>
# <tr>
# <td>2
# </td>
# <td>1
# </td>
# ...

# %%
headings= table.findAll('tr')[0]

# %%
table_headings= []
for heading in headings:
    heading= heading.text.strip()
    if len(heading)>0:
        table_headings.append(heading)
table_headings.remove('Title')
table_headings
# Out:
# ['Rank', 'Peak', 'Worldwide gross', 'Year', 'Ref']

# %%
page.findAll('th', {'class':'headerSort'})
# Out:
# []

# %%
import numpy as np
import pandas as pd

df= pd.DataFrame(columns= table_headings)
df
# Out:
# Empty DataFrame
# Columns: [Rank, Peak, Worldwide gross, Year, Ref]
# Index: []

# %%
rows= table.findAll('tr')[1:]
for row in rows:
    row_data= [data.text.strip() for data in row.findAll('td')]
    # print((row_data))
    df.loc[len(df)]= row_data
df
# Out:
#    Rank  Peak   Worldwide gross  Year           Ref
# 0     1     1    $2,923,706,026  2009    [# 1][# 2]
# 1     2     1    $2,797,501,328  2019    [# 3][# 4]
# 2     3     3    $2,320,250,281  2022    [# 5][# 6]
# 3     4     1   T$2,257,844,554  1997    [# 7][# 8]
# 4     5     3    $2,068,223,624  2015   [# 9][# 10]
# 5     6     4    $2,048,359,754  2018  [# 11][# 12]
# 6     7     6    $1,921,847,111  2021  [# 13][# 14]
# 7     8     3    $1,671,537,444  2015  [# 15][# 16]
# 8     9     7    $1,656,943,394  2019   [# 17][# 4]
# 9    10     3    $1,518,815,515  2012  [# 18][# 19]
# 10   11     4    $1,515,341,399  2015  [# 20][# 21]
# 11   12    11    $1,495,696,292  2022  [# 22][# 23]
# 12   13    10    $1,450,026,933  2019  [# 24][# 25]
# 13   14    14    $1,445,638,421  2023  [# 26][# 27]
# 14   15     5    $1,402,809,540  2015  [# 28][# 21]
# 15   16    15    $1,361,964,429  2023  [# 29][# 30]
# 16   17     9    $1,347,280,838  2018  [# 31][# 32]
# ...

# %%
titles=[]
for row in rows:
    titles.append(row.find('th').text.strip())

# %%
df['Titles']= titles

# %%
df.head()
# Out:
#   Rank Peak  Worldwide gross  Year          Ref                        Titles
# 0    1    1   $2,923,706,026  2009   [# 1][# 2]                        Avatar
# 1    2    1   $2,797,501,328  2019   [# 3][# 4]             Avengers: Endgame
# 2    3    3   $2,320,250,281  2022   [# 5][# 6]      Avatar: The Way of Water
# 3    4    1  T$2,257,844,554  1997   [# 7][# 8]                       Titanic
# 4    5    3   $2,068,223,624  2015  [# 9][# 10]  Star Wars: The Force Awakens
